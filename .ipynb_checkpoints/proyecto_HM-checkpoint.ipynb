# %%
import random

# %%
def sin_acentos(palabra):
    '''
    La funcion sin_acentos regresa una palabra sin tildes que anteriormente contenia
    tildes. 
    '''
    vocales = {"á":"a", "é":"e", "í":"i", "ó":"o", "ú":"u"}
    normalizador = str.maketrans(vocales)
    return palabra.translate(normalizador)

def leer_archivo():
    '''
    por definir
    '''
    with open("./words.txt", "r", encoding="utf-8") as file:
        lista_palabras= [sin_acentos(i.strip().lower()) for i in file]
        lista_nivel={'facil': [i for i in lista_palabras if len(i)<6],
                     'medio': [i for i in lista_palabras if 9>len(i)>6],
                     'dificil': [i for i in lista_palabras if len(i)>9]
                    }
        return(lista_nivel)        

        
def selecciona_palabra(n):
    '''
   Selecciona_palabra es una funcion que tiene como parametro la dificultad de la funcion 
   inicio, y dependiendo el valor ingresado tomara una palabra aleatoria de una BD y 
   escondera todas las letras que conforman a esa palabra. 
    
   Las letras se iran descubriendo si el usuario logra teclear aquella que pertenezca
   a la palabra, si hay mas de dos letras iguales en la palabra, la funcion lograra
   aparecer todas sin necesidad de introducir un nuevo registro.
    
   Caso contrario, si el usuario no logra introducir una letra que pertenezca, las opor-
   tunidades que tiene iran disminuyendo hasta que pierda el juego. 
    
    '''
    lectura= leer_archivo()
    
    if n==1:
        palabra= random.choice(lectura['facil'])
        descubierto=[' ? ' for i in palabra ]
        
    if n==2:
        palabra= random.choice(lectura['medio'])
        descubierto=[' ? ' for i in palabra ]
             
    if n==3:
        palabra= random.choice(lectura['dificil'])
        descubierto=[' ? ' for i in palabra ]
        
        
    flg=0    
    oportunidades= 10
    while oportunidades > 0:
        print(descubierto, "---", len(palabra), "letras,", oportunidades, 'vidas\n')
        letra = input("Adivina la palabra, ingrese un caracter válido: ")    
        if letra.isalpha() and len(letra) == 1:
            for indice in range(len(palabra)):
                if letra == palabra[indice]:
                    descubierto[indice]=letra.upper()
                    flg=flg+1
                    if flg==len(palabra):
                        return ('la palabra es:', palabra, 'Ganaste!')
            if letra not in palabra:
                oportunidades-=1
                print ('La letra',letra,'no pertenece a la palabra. Aun tienes', oportunidades, 'oportunidades más')
        else:
            print("Opcion no valida: has ingresado un caracter no valido, intenta de nuevo")
    else:
        return('Perdiste, la palabra era: ', palabra)

Intrucciones= """
Instrucciones: seleccione un nivel para jugar.
1. Fácil (4 - 6 letras)
2. Medio (7 - 9 letras)
3. Dificil (10+ letras)
              """    
def inicio():
    '''
    por definir
    
    '''
    
    
    logo = """
██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝
"""
    print(logo)
    print(Intrucciones)
    try: 
        nivel= int(input("\n\nEscoge tu nivel")) 
        if nivel==1 or nivel==2 or nivel==3:
            return selecciona_palabra(nivel)
        else:
            raise ValueError
        #if nivel!=1 or nivel!=2 or nivel!=3 or nivel==str:
            #print('el valor ingresado no es correcto. Intenta de nuevo')
            #return inicio()
    except ValueError:
        print('el valor ingresado no es correcto. Intenta de nuevo')
        return inicio()

# %%
inicio()
# Out:
# ██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
# ██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
# ███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
# ██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
# ██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
# ╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝
#
#
# Instrucciones: seleccione un nivel para jugar.
# 1. Fácil (4 - 6 letras)
# 2. Medio (7 - 9 letras)
# 3. Dificil (10+ letras)
#
#
#
# Escoge tu nivel1
# [' ? ', ' ? ', ' ? ', ' ? ', ' ? '] --- 5 letras, 10 vidas
#
# Adivina la palabra, ingrese un caracter válido: a
# La letra a no pertenece a la palabra. Aun tienes 9 oportunidades más
# [' ? ', ' ? ', ' ? ', ' ? ', ' ? '] --- 5 letras, 9 vidas
#
# Adivina la palabra, ingrese un caracter válido: e
# [' ? ', ' ? ', ' ? ', ' ? ', 'E'] --- 5 letras, 9 vidas
#
# Adivina la palabra, ingrese un caracter válido: e
# [' ? ', ' ? ', ' ? ', ' ? ', 'E'] --- 5 letras, 9 vidas
#
# Adivina la palabra, ingrese un caracter válido: e
# [' ? ', ' ? ', ' ? ', ' ? ', 'E'] --- 5 letras, 9 vidas
#
# Adivina la palabra, ingrese un caracter válido: e
# [' ? ', ' ? ', ' ? ', ' ? ', 'E'] --- 5 letras, 9 vidas
#
# Adivina la palabra, ingrese un caracter válido: e
# ('la palabra es:', 'donde', 'Ganaste!')

# %%
inicio()
# Out:
# ██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
# ██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
# ███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
# ██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
# ██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
# ╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝
#
#
# Instrucciones: seleccione un nivel para jugar.
# 1. Fácil (4 - 6 letras)
# 2. Medio (7 - 9 letras)
# 3. Dificil (10+ letras)
#
#
#
# Escoge tu nivel*9
# el valor ingresado no es correcto. Intenta de nuevo
#
# ██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
# ██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
# ███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
# ██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
# ██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
# ╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝
#
#
# Instrucciones: seleccione un nivel para jugar.
# 1. Fácil (4 - 6 letras)
# 2. Medio (7 - 9 letras)
# 3. Dificil (10+ letras)
#
#
#
# Escoge tu nivel8/
# el valor ingresado no es correcto. Intenta de nuevo
#
# ██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
# ██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
# ███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
# ██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
# ██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
# ╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝
#
#
# Instrucciones: seleccione un nivel para jugar.
# 1. Fácil (4 - 6 letras)
# 2. Medio (7 - 9 letras)
# 3. Dificil (10+ letras)
#
#
#
# Escoge tu nivel1
# [' ? ', ' ? ', ' ? ', ' ? ', ' ? '] --- 5 letras, 10 vidas
#
# Adivina la palabra, ingrese un caracter válido: a
# [' ? ', ' ? ', ' ? ', 'a', ' ? '] --- 5 letras, 10 vidas
#
# Adivina la palabra, ingrese un caracter válido: e
# La letra e no pertenece a la palabra. Aun tienes 9 oportunidades más
# [' ? ', ' ? ', ' ? ', 'a', ' ? '] --- 5 letras, 9 vidas
#
# Adivina la palabra, ingrese un caracter válido: i
# La letra i no pertenece a la palabra. Aun tienes 8 oportunidades más
# [' ? ', ' ? ', ' ? ', 'a', ' ? '] --- 5 letras, 8 vidas
#
# Adivina la palabra, ingrese un caracter válido: o
# [' ? ', 'o', ' ? ', 'a', ' ? '] --- 5 letras, 8 vidas
#
# Adivina la palabra, ingrese un caracter válido: u
# La letra u no pertenece a la palabra. Aun tienes 7 oportunidades más
# [' ? ', 'o', ' ? ', 'a', ' ? '] --- 5 letras, 7 vidas
#
# Adivina la palabra, ingrese un caracter válido: c
# La letra c no pertenece a la palabra. Aun tienes 6 oportunidades más
# [' ? ', 'o', ' ? ', 'a', ' ? '] --- 5 letras, 6 vidas
#
# Adivina la palabra, ingrese un caracter válido: m
# La letra m no pertenece a la palabra. Aun tienes 5 oportunidades más
# [' ? ', 'o', ' ? ', 'a', ' ? '] --- 5 letras, 5 vidas
#
# Adivina la palabra, ingrese un caracter válido: r
# ['r', 'o', ' ? ', 'a', 'r'] --- 5 letras, 5 vidas
#
# Adivina la palabra, ingrese un caracter válido: q
# La letra q no pertenece a la palabra. Aun tienes 4 oportunidades más
# ['r', 'o', ' ? ', 'a', 'r'] --- 5 letras, 4 vidas
#
# Adivina la palabra, ingrese un caracter válido: w
# La letra w no pertenece a la palabra. Aun tienes 3 oportunidades más
# ['r', 'o', ' ? ', 'a', 'r'] --- 5 letras, 3 vidas
#
# Adivina la palabra, ingrese un caracter válido: e
# La letra e no pertenece a la palabra. Aun tienes 2 oportunidades más
# ['r', 'o', ' ? ', 'a', 'r'] --- 5 letras, 2 vidas
#
# Adivina la palabra, ingrese un caracter válido: r
# ('la palabra es:', 'rodar', 'Ganaste!')

# %%
inicio()
# Out:
# ██╗░░██╗░█████╗░███╗░░██╗░██████╗░███╗░░░███╗░█████╗░███╗░░██╗
# ██║░░██║██╔══██╗████╗░██║██╔════╝░████╗░████║██╔══██╗████╗░██║
# ███████║███████║██╔██╗██║██║░░██╗░██╔████╔██║███████║██╔██╗██║
# ██╔══██║██╔══██║██║╚████║██║░░╚██╗██║╚██╔╝██║██╔══██║██║╚████║
# ██║░░██║██║░░██║██║░╚███║╚██████╔╝██║░╚═╝░██║██║░░██║██║░╚███║
# ╚═╝░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝░╚═════╝░╚═╝░░░░░╚═╝╚═╝░░╚═╝╚═╝░░╚══╝
#
#
# Instrucciones: seleccione un nivel para jugar.
# 1. Fácil (4 - 6 letras)
# 2. Medio (7 - 9 letras)
# 3. Dificil (10+ letras)
#
#
#
# Escoge tu nivel1
# [' ? ', ' ? ', ' ? ', ' ? ', ' ? '] --- 5 letras, 10 vidas
#
# Adivina la palabra, ingrese un caracter válido: a
# [' ? ', 'a', ' ? ', 'a', ' ? '] --- 5 letras, 10 vidas
#
# Adivina la palabra, ingrese un caracter válido: c
# ['c', 'a', ' ? ', 'a', ' ? '] --- 5 letras, 10 vidas
#
# Adivina la palabra, ingrese un caracter válido: s
# La letra s no pertenece a la palabra. Aun tienes 9 oportunidades más
# ['c', 'a', ' ? ', 'a', ' ? '] --- 5 letras, 9 vidas
#
# Adivina la palabra, ingrese un caracter válido: z
# La letra z no pertenece a la palabra. Aun tienes 8 oportunidades más
# ['c', 'a', ' ? ', 'a', ' ? '] --- 5 letras, 8 vidas
#
# Adivina la palabra, ingrese un caracter válido: r
# La letra r no pertenece a la palabra. Aun tienes 7 oportunidades más
# ['c', 'a', ' ? ', 'a', ' ? '] --- 5 letras, 7 vidas
#
# Adivina la palabra, ingrese un caracter válido: t
# La letra t no pertenece a la palabra. Aun tienes 6 oportunidades más
# ['c', 'a', ' ? ', 'a', ' ? '] --- 5 letras, 6 vidas
#
# Adivina la palabra, ingrese un caracter válido: l
# ['c', 'a', ' ? ', 'a', 'l'] --- 5 letras, 6 vidas
#
# Adivina la palabra, ingrese un caracter válido: c
# ('la palabra es:', 'canal', 'Ganaste!')
